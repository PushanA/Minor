# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import cv2
import random
import gc
import seaborn as sns
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import load_img
import keras,os
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation,GlobalMaxPooling2D
import numpy as np
from sklearn.model_selection import train_test_split
from keras.applications.vgg19 import VGG19
from keras.models import Model
from keras import optimizers , layers, applications
Adam=tf.keras.optimizers.Adam()

# %%
train_data = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
train_filenames = os.listdir("/content/drive/MyDrive/AutismDataset/train")
categories = []
for filename in train_filenames:
    category = filename.split('.')[0]
    if category == 'Autistic':
        categories.append(str(1))
    else:
        categories.append(str(0))

train_df = pd.DataFrame({
    'filename': train_filenames,
    'category': categories
})

# %%
train_df.head()
# Out:
#                 filename category
# 0  Non_Autistic.1252.jpg        0
# 1  Non_Autistic.1242.jpg        0
# 2  Non_Autistic.1186.jpg        0
# 3  Non_Autistic.1239.jpg        0
# 4  Non_Autistic.1232.jpg        0

# %%
test_data = ImageDataGenerator(rescale=1./255)

# %%
test_filenames = os.listdir("/content/drive/MyDrive/AutismDataset/test")
categories = []
for filename in test_filenames:
    category = filename.split('.')[0]
    if category == 'Autistic':
        categories.append(str(1))
    else:
        categories.append(str(0))

test_df = pd.DataFrame({
    'filename': test_filenames,
    'category': categories
})

# %%
test_df.head()
# Out:
#            filename category
# 0  Autistic.100.jpg        1
# 1  Autistic.103.jpg        1
# 2    Autistic.1.jpg        1
# 3  Autistic.101.jpg        1
# 4    Autistic.0.jpg        1

# %%
sample = random.choice(train_filenames)
image = load_img("/content/drive/MyDrive/AutismDataset/train/"+sample)
plt.imshow(image)

# %%
sample_test = random.choice(test_filenames)
image= load_img("/content/drive/MyDrive/AutismDataset/test/"+sample_test)
plt.imshow(image)

# %% [markdown]
# **VGG-19 MODEL**

# %%
image_size = 224
input_shape = (image_size, image_size,3)

#Hyperparameters
epochs = 30
batch_size = 32

pre_trained_model = VGG19(input_shape=input_shape, include_top=False, weights="imagenet")
    
for layer in pre_trained_model.layers:
    layer.trainable = False

# Flatten the output layer to 1 dimension
x = keras.models.Sequential()
x.add(pre_trained_model)
x.add(layers.Flatten())
# Add a fully connected layer with 128 hidden units and ReLU activation
x.add(layers.Dense(512, activation='relu'))
# Add a dropout rate of 0.5
x.add(layers.Dropout(0.5))
# Add a fully connected layer with 64 hidden units and ReLU activation
#x.add(layers.Dense(64, activation='relu'))
# Add a final sigmoid layer for classification
x.add(layers.Dense(1, activation='sigmoid'))

x.compile(loss='binary_crossentropy',
             optimizer =  tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

x.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 32,870,465
# Trainable params: 12,846,081
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
val_data = ImageDataGenerator(rescale = 1./255)

# %%
train_df, validate_df = train_test_split(train_df, test_size=0.1)
train_df = train_df.reset_index()
validate_df = validate_df.reset_index()

total_train = train_df.shape[0]
total_validate = validate_df.shape[0]

# %%
train_generator = train_data.flow_from_dataframe(
    train_df, 
    "/content/drive/MyDrive/AutismDataset/train", 
    x_col='filename',
    y_col='category',
    class_mode='binary',
    target_size=(image_size, image_size),
    batch_size=batch_size
)
# Out:
# Found 2286 validated image filenames belonging to 2 classes.

# %%
# Validation Generator
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "/content/drive/MyDrive/AutismDataset/train", 
    x_col='filename',
    y_col='category',
    class_mode='binary',
    target_size=(image_size, image_size),
    batch_size=batch_size
)
# Out:
# Found 254 validated image filenames belonging to 2 classes.

# %%
#Fit Model
history = x.fit_generator(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=72)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/30
# 72/72 [==============================] - 1903s 26s/step - loss: 1.2846 - accuracy: 0.6671 - val_loss: 0.4725 - val_accuracy: 0.7634
# Epoch 2/30
# 72/72 [==============================] - 35s 489ms/step - loss: 0.5163 - accuracy: 0.7485 - val_loss: 0.4865 - val_accuracy: 0.7321
# Epoch 3/30
# 72/72 [==============================] - 34s 477ms/step - loss: 0.5054 - accuracy: 0.7563 - val_loss: 0.4263 - val_accuracy: 0.7812
# Epoch 4/30
# 72/72 [==============================] - 34s 476ms/step - loss: 0.4868 - accuracy: 0.7563 - val_loss: 0.3850 - val_accuracy: 0.8080
# Epoch 5/30
# 72/72 [==============================] - 34s 478ms/step - loss: 0.4619 - accuracy: 0.7769 - val_loss: 0.4163 - val_accuracy: 0.7946
# Epoch 6/30
# 72/72 [==============================] - 35s 489ms/step - loss: 0.4550 - accuracy: 0.7808 - val_loss: 0.4191 - val_accuracy: 0.7902
# Epoch 7/30
# 72/72 [==============================] - 34s 478ms/step - loss: 0.4294 - accuracy: 0.7927 - val_loss: 0.4094 - val_accuracy: 0.7902
# Epoch 8/30
# 72/72 [==============================] - 35s 479ms/step - loss: 0.4329 - accuracy: 0.8014 - val_loss: 0.3856 - val_accuracy: 0.7991
# Epoch 9/30
# 72/72 [==============================] - 35s 490ms/step - loss: 0.4548 - accuracy: 0.7795 - val_loss: 0.4662 - val_accuracy: 0.7723
# Epoch 10/30
# 72/72 [==============================] - 34s 476ms/step - loss: 0.4201 - accuracy: 0.8027 - val_loss: 0.3764 - val_accuracy: 0.8036
# Epoch 11/30
# 72/72 [==============================] - 34s 477ms/step - loss: 0.4270 - accuracy: 0.7997 - val_loss: 0.3939 - val_accuracy: 0.7902
# Epoch 12/30
# 72/72 [==============================] - 35s 478ms/step - loss: 0.4335 - accuracy: 0.7992 - val_loss: 0.3819 - val_accuracy: 0.8125
# Epoch 13/30
# 72/72 [==============================] - 35s 490ms/step - loss: 0.4572 - accuracy: 0.7830 - val_loss: 0.4085 - val_accuracy: 0.7723
# Epoch 14/30
# 72/72 [==============================] - 35s 478ms/step - loss: 0.4383 - accuracy: 0.7983 - val_loss: 0.3915 - val_accuracy: 0.7946
# Epoch 15/30
# 72/72 [==============================] - 34s 477ms/step - loss: 0.4284 - accuracy: 0.7988 - val_loss: 0.4292 - val_accuracy: 0.7634
# Epoch 16/30
# 72/72 [==============================] - 36s 492ms/step - loss: 0.4160 - accuracy: 0.8145 - val_loss: 0.3831 - val_accuracy: 0.7857
# Epoch 17/30
# 72/72 [==============================] - 35s 480ms/step - loss: 0.4137 - accuracy: 0.8036 - val_loss: 0.3620 - val_accuracy: 0.8259
# Epoch 18/30
# 72/72 [==============================] - 34s 478ms/step - loss: 0.3930 - accuracy: 0.8246 - val_loss: 0.3566 - val_accuracy: 0.8259
# Epoch 19/30
# 72/72 [==============================] - 34s 476ms/step - loss: 0.3972 - accuracy: 0.8062 - val_loss: 0.3857 - val_accuracy: 0.8080
# Epoch 20/30
# 72/72 [==============================] - 35s 489ms/step - loss: 0.4014 - accuracy: 0.8176 - val_loss: 0.4292 - val_accuracy: 0.7812
# Epoch 21/30
# 72/72 [==============================] - 34s 477ms/step - loss: 0.4099 - accuracy: 0.7957 - val_loss: 0.3718 - val_accuracy: 0.7902
# Epoch 22/30
# 72/72 [==============================] - 34s 478ms/step - loss: 0.3957 - accuracy: 0.8136 - val_loss: 0.3748 - val_accuracy: 0.7946
# Epoch 23/30
# 72/72 [==============================] - 36s 493ms/step - loss: 0.3811 - accuracy: 0.8198 - val_loss: 0.3561 - val_accuracy: 0.8170
# Epoch 24/30
# 72/72 [==============================] - 34s 477ms/step - loss: 0.4225 - accuracy: 0.7975 - val_loss: 0.4277 - val_accuracy: 0.7812
# Epoch 25/30
# 72/72 [==============================] - 35s 478ms/step - loss: 0.4075 - accuracy: 0.8001 - val_loss: 0.3786 - val_accuracy: 0.7991
# Epoch 26/30
# 72/72 [==============================] - 35s 492ms/step - loss: 0.3772 - accuracy: 0.8298 - val_loss: 0.3720 - val_accuracy: 0.8125
# Epoch 27/30
# 72/72 [==============================] - 34s 477ms/step - loss: 0.3739 - accuracy: 0.8276 - val_loss: 0.3873 - val_accuracy: 0.7991
# Epoch 28/30
# 72/72 [==============================] - 35s 480ms/step - loss: 0.3621 - accuracy: 0.8346 - val_loss: 0.3821 - val_accuracy: 0.8170
# Epoch 29/30
# 72/72 [==============================] - 34s 476ms/step - loss: 0.4262 - accuracy: 0.7699 - val_loss: 0.4071 - val_accuracy: 0.7768
# Epoch 30/30
# 72/72 [==============================] - 36s 492ms/step - loss: 0.3947 - accuracy: 0.8110 - val_loss: 0.3550 - val_accuracy: 0.8393
